# %%
import numpy as np
import pandas as pd
import nltk

# %%
train_df= pd.read_csv('train_data.csv')
test_df= pd.read_csv('test_data.csv')

# %%
answer= []

SSP= nltk.tokenize.SyllableTokenizer()

for _, row in test_df:
    SYL= len(SSP.tokenize(row['text_content']))



pd.DataFrame(answer).to_csv("submission.csv", index= False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 SSP= nltk.tokenize.SyllableTokenizer()
#       5 for _, row in test_df:
# ----> 6     SYL= len(SSP.tokenize(row['text_content']))
#      10 pd.DataFrame(answer).to_csv("submission.csv", index= False)
#
# TypeError: string indices must be integers
